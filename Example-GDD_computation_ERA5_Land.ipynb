# %%
using GRIB

Y = 2017

#Temperature data of the year of interest from ERA5-Land in .grib format
infilename = "GRIB_files/Spain_$(Y).grib" 

outfolder = "GDD_data/$(Y)"

if ! isdir(outfolder)
    
    mkdir(outfolder)
    
end

#Filename to save the daily GDD output data
outfilename = "GDD_data/$(Y)/PS_GDD"

T_base =  9.2 + 273.15 #9.2 + 273.15 #9 + 273.15
T_opt = 23.4 + 273.15 #27.6 + 273.15 #27.4 + 273.15
T_max = 34.2 + 273.15 #41.8 + 273.15 #41.2 + 273.15

#Compute GDD by month
@time GribFile(infilename) do f

    m = Message(f)
    
    GDD = zeros(size(vec(m["values"])))
    
    current_day = 1
    
    message_prev = m
    
    for message in f

        T = vec(message["values"])
        day = Int(message["day"])
        
        #write GDD for this month
        if day != current_day
            
            date = string(current_day, "_", message_prev["month"], "_", message_prev["year"])
            
            println("Writing ", date)
           
            lats = message["latitudes"]
            lons = message["longitudes"]
            
            shape = (size(message["values"])[2], size(message["values"])[1])
            
            file = open(string(outfilename, "_", date, ".txt"), "w")
            
            println(file, "#GDD\tLongitudes\tLatitudes\tshape=$shape")
            
            for i in 1 : length(GDD)
                
                println(file, GDD[i] / 24.0, "\t", round(lons[i], digits=4), "\t", round(lats[i], digits=4))
                
            end
            
            close(file)
            
            current_day = day
            GDD = zeros(size(vec(message["values"])))
            
        end
        
        A = - (T_opt - T_base) / (T_max - T_opt)
        B = -A * T_max

        for i in eachindex(T)

                if T[i] < T_base
               
                    #Nothing            

                elseif T[i] <= T_opt
                    
                    GDD[i] += (T[i] - T_base)
                
                elseif T[i] <= T_max
            
                    GDD[i] += (A*T[i] + B)
                
                end

        end
        
        message_prev = message
        
    end
    
    current_day = 31
    
    date = string(current_day, "_", message_prev["month"], "_", message_prev["year"])
            
    println("Writing ", date)

    lats = m["latitudes"]
    lons = m["longitudes"]

    shape = (size(m["values"])[2], size(m["values"])[1])

    file = open(string(outfilename, "_", date, ".txt"), "w")

    println(file, "#GDD\tLongitudes\tLatitudes\tshape=$shape")

    for i in 1 : length(GDD)

        println(file, GDD[i] / 24.0, "\t", round(lons[i], digits=4), "\t", round(lats[i], digits=4))

    end

    close(file)
    
end
# Out:
# Writing 1_1_2017
# Writing 2_1_2017
# Writing 3_1_2017
# Writing 4_1_2017
# Writing 5_1_2017
# Writing 6_1_2017
# Writing 7_1_2017
# Writing 8_1_2017
# Writing 9_1_2017
# Writing 10_1_2017
# Writing 11_1_2017
# Writing 12_1_2017
# Writing 13_1_2017
# Writing 14_1_2017
# Writing 15_1_2017
# Writing 16_1_2017
# Writing 17_1_2017
# Writing 18_1_2017
# Writing 19_1_2017
# Writing 20_1_2017
# Writing 21_1_2017
# Writing 22_1_2017
# Writing 23_1_2017
# Writing 24_1_2017
# Writing 25_1_2017
# Writing 26_1_2017
# Writing 27_1_2017
# Writing 28_1_2017
# Writing 29_1_2017
# Writing 30_1_2017
# Writing 31_1_2017
# Writing 1_2_2017
# Writing 2_2_2017
# Writing 3_2_2017
# Writing 4_2_2017
# Writing 5_2_2017
# Writing 6_2_2017
# Writing 7_2_2017
# Writing 8_2_2017
# Writing 9_2_2017
# Writing 10_2_2017
# Writing 11_2_2017
# Writing 12_2_2017
# Writing 13_2_2017
# Writing 14_2_2017
# Writing 15_2_2017
# Writing 16_2_2017
# Writing 17_2_2017
# Writing 18_2_2017
# Writing 19_2_2017
# Writing 20_2_2017
# Writing 21_2_2017
# Writing 22_2_2017
# Writing 23_2_2017
# Writing 24_2_2017
# Writing 25_2_2017
# Writing 26_2_2017
# Writing 27_2_2017
# Writing 28_2_2017
# Writing 1_3_2017
# Writing 2_3_2017
# Writing 3_3_2017
# Writing 4_3_2017
# Writing 5_3_2017
# Writing 6_3_2017
# Writing 7_3_2017
# Writing 8_3_2017
# Writing 9_3_2017
# Writing 10_3_2017
# Writing 11_3_2017
# Writing 12_3_2017
# Writing 13_3_2017
# Writing 14_3_2017
# Writing 15_3_2017
# Writing 16_3_2017
# Writing 17_3_2017
# Writing 18_3_2017
# Writing 19_3_2017
# Writing 20_3_2017
# Writing 21_3_2017
# Writing 22_3_2017
# Writing 23_3_2017
# Writing 24_3_2017
# Writing 25_3_2017
# Writing 26_3_2017
# Writing 27_3_2017
# Writing 28_3_2017
# Writing 29_3_2017
# Writing 30_3_2017
# Writing 31_3_2017
# Writing 1_4_2017
# Writing 2_4_2017
# Writing 3_4_2017
# Writing 4_4_2017
# Writing 5_4_2017
# Writing 6_4_2017
# Writing 7_4_2017
# Writing 8_4_2017
# Writing 9_4_2017
# Writing 10_4_2017
# Writing 11_4_2017
# Writing 12_4_2017
# Writing 13_4_2017
# Writing 14_4_2017
# Writing 15_4_2017
# Writing 16_4_2017
# Writing 17_4_2017
# Writing 18_4_2017
# Writing 19_4_2017
# Writing 20_4_2017
# Writing 21_4_2017
# Writing 22_4_2017
# Writing 23_4_2017
# Writing 24_4_2017
# Writing 25_4_2017
# Writing 26_4_2017
# Writing 27_4_2017
# Writing 28_4_2017
# Writing 29_4_2017
# Writing 30_4_2017
# Writing 1_5_2017
# Writing 2_5_2017
# Writing 3_5_2017
# Writing 4_5_2017
# Writing 5_5_2017
# Writing 6_5_2017
# Writing 7_5_2017
# Writing 8_5_2017
# Writing 9_5_2017
# Writing 10_5_2017
# Writing 11_5_2017
# Writing 12_5_2017
# Writing 13_5_2017
# Writing 14_5_2017
# Writing 15_5_2017
# Writing 16_5_2017
# Writing 17_5_2017
# Writing 18_5_2017
# Writing 19_5_2017
# Writing 20_5_2017
# Writing 21_5_2017
# Writing 22_5_2017
# Writing 23_5_2017
# Writing 24_5_2017
# Writing 25_5_2017
# Writing 26_5_2017
# Writing 27_5_2017
# Writing 28_5_2017
# Writing 29_5_2017
# Writing 30_5_2017
# Writing 31_5_2017
# Writing 1_6_2017
# Writing 2_6_2017
# Writing 3_6_2017
# Writing 4_6_2017
# Writing 5_6_2017
# Writing 6_6_2017
# Writing 7_6_2017
# Writing 8_6_2017
# Writing 9_6_2017
# Writing 10_6_2017
# Writing 11_6_2017
# Writing 12_6_2017
# Writing 13_6_2017
# Writing 14_6_2017
# Writing 15_6_2017
# Writing 16_6_2017
# Writing 17_6_2017
# Writing 18_6_2017
# Writing 19_6_2017
# Writing 20_6_2017
# Writing 21_6_2017
# Writing 22_6_2017
# Writing 23_6_2017
# Writing 24_6_2017
# Writing 25_6_2017
# Writing 26_6_2017
# Writing 27_6_2017
# Writing 28_6_2017
# Writing 29_6_2017
# Writing 30_6_2017
# Writing 1_7_2017
# Writing 2_7_2017
# Writing 3_7_2017
# Writing 4_7_2017
# Writing 5_7_2017
# Writing 6_7_2017
# Writing 7_7_2017
# Writing 8_7_2017
# Writing 9_7_2017
# Writing 10_7_2017
# Writing 11_7_2017
# Writing 12_7_2017
# Writing 13_7_2017
# Writing 14_7_2017
# Writing 15_7_2017
# Writing 16_7_2017
# Writing 17_7_2017
# Writing 18_7_2017
# Writing 19_7_2017
# Writing 20_7_2017
# Writing 21_7_2017
# Writing 22_7_2017
# Writing 23_7_2017
# Writing 24_7_2017
# Writing 25_7_2017
# Writing 26_7_2017
# Writing 27_7_2017
# Writing 28_7_2017
# Writing 29_7_2017
# Writing 30_7_2017
# Writing 31_7_2017
# Writing 1_8_2017
# Writing 2_8_2017
# Writing 3_8_2017
# Writing 4_8_2017
# Writing 5_8_2017
# Writing 6_8_2017
# Writing 7_8_2017
# Writing 8_8_2017
# Writing 9_8_2017
# Writing 10_8_2017
# Writing 11_8_2017
# Writing 12_8_2017
# Writing 13_8_2017
# Writing 14_8_2017
# Writing 15_8_2017
# Writing 16_8_2017
# Writing 17_8_2017
# Writing 18_8_2017
# Writing 19_8_2017
# Writing 20_8_2017
# Writing 21_8_2017
# Writing 22_8_2017
# Writing 23_8_2017
# Writing 24_8_2017
# Writing 25_8_2017
# Writing 26_8_2017
# Writing 27_8_2017
# Writing 28_8_2017
# Writing 29_8_2017
# Writing 30_8_2017
# Writing 31_8_2017
# Writing 1_9_2017
# Writing 2_9_2017
# Writing 3_9_2017
# Writing 4_9_2017
# Writing 5_9_2017
# Writing 6_9_2017
# Writing 7_9_2017
# Writing 8_9_2017
# Writing 9_9_2017
# Writing 10_9_2017
# Writing 11_9_2017
# Writing 12_9_2017
# Writing 13_9_2017
# Writing 14_9_2017
# Writing 15_9_2017
# Writing 16_9_2017
# Writing 17_9_2017
# Writing 18_9_2017
# Writing 19_9_2017
# Writing 20_9_2017
# Writing 21_9_2017
# Writing 22_9_2017
# Writing 23_9_2017
# Writing 24_9_2017
# Writing 25_9_2017
# Writing 26_9_2017
# Writing 27_9_2017
# Writing 28_9_2017
# Writing 29_9_2017
# Writing 30_9_2017
# Writing 1_10_2017
# Writing 2_10_2017
# Writing 3_10_2017
# Writing 4_10_2017
# Writing 5_10_2017
# Writing 6_10_2017
# Writing 7_10_2017
# Writing 8_10_2017
# Writing 9_10_2017
# Writing 10_10_2017
# Writing 11_10_2017
# Writing 12_10_2017
# Writing 13_10_2017
# Writing 14_10_2017
# Writing 15_10_2017
# Writing 16_10_2017
# Writing 17_10_2017
# Writing 18_10_2017
# Writing 19_10_2017
# Writing 20_10_2017
# Writing 21_10_2017
# Writing 22_10_2017
# Writing 23_10_2017
# Writing 24_10_2017
# Writing 25_10_2017
# Writing 26_10_2017
# Writing 27_10_2017
# Writing 28_10_2017
# Writing 29_10_2017
# Writing 30_10_2017
# Writing 31_10_2017
# Writing 1_11_2017
# Writing 2_11_2017
# Writing 3_11_2017
# Writing 4_11_2017
# Writing 5_11_2017
# Writing 6_11_2017
# Writing 7_11_2017
# Writing 8_11_2017
# Writing 9_11_2017
# Writing 10_11_2017
# Writing 11_11_2017
# Writing 12_11_2017
# Writing 13_11_2017
# Writing 14_11_2017
# Writing 15_11_2017
# Writing 16_11_2017
# Writing 17_11_2017
# Writing 18_11_2017
# Writing 19_11_2017
# Writing 20_11_2017
# Writing 21_11_2017
# Writing 22_11_2017
# Writing 23_11_2017
# Writing 24_11_2017
# Writing 25_11_2017
# Writing 26_11_2017
# Writing 27_11_2017
# Writing 28_11_2017
# Writing 29_11_2017
# Writing 30_11_2017
# Writing 1_12_2017
# Writing 2_12_2017
# Writing 3_12_2017
# Writing 4_12_2017
# Writing 5_12_2017
# Writing 6_12_2017
# Writing 7_12_2017
# Writing 8_12_2017
# Writing 9_12_2017
# Writing 10_12_2017
# Writing 11_12_2017
# Writing 12_12_2017
# Writing 13_12_2017
# Writing 14_12_2017
# Writing 15_12_2017
# Writing 16_12_2017
# Writing 17_12_2017
# Writing 18_12_2017
# Writing 19_12_2017
# Writing 20_12_2017
# Writing 21_12_2017
# Writing 22_12_2017
# Writing 23_12_2017
# Writing 24_12_2017
# Writing 25_12_2017
# Writing 26_12_2017
# Writing 27_12_2017
# Writing 28_12_2017
# Writing 29_12_2017
# Writing 30_12_2017
# Writing 31_12_2017
#  48.609632 seconds (1.05 G allocations: 25.401 GiB, 5.08% gc time, 0.02% compilation time)
